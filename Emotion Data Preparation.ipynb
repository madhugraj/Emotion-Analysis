# %%
import csv
import pandas as pd

# %%
emotion_df =  pd.read_csv('Train_300.csv')
emotion_df.head()
# Out:
#      i feel so enraged but helpless at the same time  0
# 0                    i said feeling a bit rebellious  0
# 1  i woke up feeling particularly vile tried to i...  0
# 2  i could feel the vile moth burrowing its way i...  0
# 3  i have a pretty bad feeling the last two books...  0
# 4  im looking right now so desperately looking fo...  0

# %%
emotion_samp= emotion_df.sample(n=150)
emotion_samp.to_csv('Test1_150.csv')

# %%
emotion_samp
# Out:
#        i feel so enraged but helpless at the same time  0
# 104  i like super committed like to the point where...  2
# 226          i feel strange or will i ever notice that  4
# 37   i could feel the poisoned hateful angry buildu...  0
# 73   i was feeling so distressed so it has been add...  1
# 291  i feel you as my best man someone who moves me...  5
# 119                       i feel as though im carefree  2
# 210  i distinctly remember saying i miss being at h...  4
# 274  i feel that some of you loyal pistons fans are...  5
# 258  i am feeling in a naughty and rebellious mood ...  5
# 208  i have been feeling amazing on this cleanse da...  4
# 167  i am abused or i feel like i am abused comes a...  3
# 44   i don t feel insulted at all it s more like fe...  0
# 213  i catch her doing something she should not and...  4
# 172  im trying to type what i feel youre getting bl...  3
# 76   i think if i reached deep enough into the disa...  1
# ...
